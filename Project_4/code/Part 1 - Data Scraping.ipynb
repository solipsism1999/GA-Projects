# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 4: Nutri-Grade labels

# %% [markdown]
# ---
# ## Problem Statement
# Singaporeans are living longer but spending more time in ill-health. There are top 3 chronic medical conditions that Singaporeans suffer from are: Hypertension, Diabetes and Hyperlipidemia<br>
#
# There are 3 main ways to prevent chronic illness:
# - Physical Activity (Engage in at least 150-300 minutes of moderate-intensity aerobic activity in a week)
# - Diet (Consume the receommended dietary allowances for sugar, saturated fat and salt)
# - Healthy life choices (Avoid tobacco and excessive drinking)<br>
#
# We will focus on the diet portion. More than half of Singaporeans’ daily sugar intake comes from beverages. This is why the government has came up with a nutri-grade labelling system in hopes that Singaporeans will reduce their sugar intake by making heatheir choices when choosing which drink to buy. However the nutrigrade labels only take into account trans fat and sugar and do not provide a holistic picture of the health of the drinks. Is there a way to create a more comprehensive indicator of how healthy drinks are?

# %% [markdown]
# ## Contents:
# - [Import libraries](#Import-libraries)
# - [Data scraping](#Data-scraping)

# %% [markdown]
# # Import libraries

# %%
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# # Data scraping
#
# Here, we use selenium and beautiful soup to get the nutritional information of drinks from the supermarket website. The supermarket we have chosen is NTUC FairPrice. We chose to get the information from 4 categories of drinks:
# - Coffee
# - Tea
# - Juice
# - Drinks

# %%
# Initialize the Selenium WebDriver
driver = webdriver.Chrome()

# Navigate to the webpage
url = 'https://www.fairprice.com.sg/category/coffee'
driver.get(url)

# Wait for the page to load
time.sleep(10)

# Scroll to load more products
num_scrolls = 40
for _ in range(num_scrolls):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(10)

# Extract links to individual product pages
product_links = []
soup = BeautifulSoup(driver.page_source, 'html.parser')
product_cards = soup.find_all('div', class_='sc-2a85da88-0 fhLHEV product-container')

# Assuming product_cards contains the relevant div elements with class 'sc-2a85da88-0'
for card in product_cards:
    a_tag = card.find('a', class_='sc-2a85da88-3')
    if a_tag:
        product_link = a_tag['href']
        product_links.append(product_link)

# Extract nutritional data for each product
all_nutritional_data = []

for product_link in product_links:
    product_url = f'https://www.fairprice.com.sg{product_link}'
    driver.get(product_url)
    time.sleep(4)

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    nutritional_data = {}

    # Extracting the drink's volume
    volume = soup.find('span', class_='sc-aa673588-1 sc-d5ac8310-3 kZssPC jGBApJ')
    if volume:
        nutritional_data['Drink Volume'] = volume.text

    # Extracting the drink's name
    drink_name = soup.find('span', class_='sc-aa673588-1 drdope')
    if drink_name:
        nutritional_data['Drink Name'] = drink_name.text

    nutrient_list = soup.find('ul', class_='sc-ad6d339b-0 lhIfvG')
    if nutrient_list:
        nutrient_rows = nutrient_list.find_all('li', class_='sc-ad6d339b-1 iVtCiL')
        first_row = nutrient_rows[0]
        attributes_name = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU')
        attributes_value = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT')
        for attr_name, attr_value in zip(attributes_name, attributes_value):
            attribute_name = attr_name.text.strip()
            attribute_value = attr_value.text.strip()
            nutritional_data[attribute_name] = attribute_value
        for row in nutrient_rows[1:]:
            nutrient_name = row.find('span', class_='sc-ilhmMj').text.strip()
            nutrient_value = row.find('span', class_='sc-ilhmMj fQpIpK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT').text.strip()
            nutritional_data[nutrient_name] = nutrient_value

    all_nutritional_data.append(nutritional_data)

# Close the Selenium WebDriver
driver.quit()

# Create a DataFrame from the nutritional data
df = pd.DataFrame(all_nutritional_data)

# Remove the rows that have NaN in every column
# Drop rows where all columns except 'Drink Name' and 'Drink Volume' have NaN
df.dropna(subset=df.columns.difference(['Drink Name', 'Drink Volume']), how='all', inplace=True)

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# Print the DataFrame after removing rows with NaN
df
# Out:
#     Drink Volume                                         Drink Name  \
# 0           392g  Milkmaid Sweetened Condensed Milk - Full Cream...
# 1          600 G                       Killiney 3-in-1 White Coffee
# 2           200g                              Nescafe Gold Original
# 3           450g                  Nestle Coffeemate Creamer - Pouch
# 4      100 x 20g                 Indocafe 3 in 1 Instant Coffee Mix
# ..           ...                                                ...
# 137        250 G  Cafe specialists Traditional Signature Ground ...
# 138        270 G                                Mycofe Long Black O
# 139     6 X 260G          UCC Blended Coffee Luxurious Cafe Au Lait
# 140     6 X 185G           UCC Black 100% Roasted Coffee Sugar Free
# 141        120 G  AGF Slightly Luxurious Coffee Shop Instant Cof...
#
#              Attributes  Energy Protein Total Fat Carbohydrate Calcium  \
# 0     Per Serving (20g)  65kcal    1.4g      1.6g        11.2g    52mg
# 1    Per Serving (1.1g)     NaN    1.1g       NaN          NaN     NaN
# 2             Per 100ml   4kcal    0.3g      0.0g         0.7g     NaN
# 3      Per Serving (6g)  33kcal    0.1g      2.1g         3.4g     NaN
# 4     Per Serving (20g)  90kcal    < 1g        2g          NaN     NaN
# ..                  ...     ...     ...       ...          ...     ...
# 137  Per Serving (2.5g)  50kcal    2.5g       NaN          10g     NaN
# 138    Per Serving (18)     NaN    0.9g        0g          NaN     NaN
# 139      Per Serving ()     NaN    0.6g       NaN          NaN     NaN
# 140      Per Serving ()     NaN     NaN       NaN          NaN     NaN
# 141      Per Serving ()     NaN     NaN       NaN          NaN     NaN
#
#     Vitamin A Vitamin B1  ... Vitamin D Total Calorieso  \
# 0        42µg      0.2mg  ...       NaN             NaN
# 1         NaN        NaN  ...       NaN             NaN
# 2         NaN        NaN  ...       NaN             NaN
# 3         NaN        NaN  ...       NaN             NaN
# 4         NaN        NaN  ...       NaN             NaN
# ..        ...        ...  ...       ...             ...
# 137       NaN        NaN  ...       NaN             NaN
# 138       NaN        NaN  ...       NaN             NaN
# 139       NaN        NaN  ...       NaN             NaN
# 140       NaN        NaN  ...       NaN             NaN
# 141       NaN        NaN  ...       NaN             NaN
#
#     Calories From Saturated Fat Salt (Sodium) Serving TotalSugers  \
# 0                           NaN           NaN     NaN         NaN
# 1                           NaN           NaN     NaN         NaN
# 2                           NaN           NaN     NaN         NaN
# 3                           NaN           NaN     NaN         NaN
# 4                           NaN           NaN     NaN         NaN
# ..                          ...           ...     ...         ...
# 137                         NaN           NaN     NaN         NaN
# 138                         NaN           NaN     NaN         NaN
# 139                         NaN           NaN     NaN         NaN
# 140                         NaN           NaN     NaN         NaN
# 141                         NaN           NaN     NaN         NaN
#
#     Monosaturated Fat Satutated Fat Total Dietary Fiber Enery
# 0                 NaN           NaN                 NaN   NaN
# 1                 NaN           NaN                 NaN   NaN
# 2                 NaN           NaN                 NaN   NaN
# 3                 NaN           NaN                 NaN   NaN
# 4                 NaN           NaN                 NaN   NaN
# ..                ...           ...                 ...   ...
# 137               NaN           NaN                 NaN   NaN
# 138               NaN           NaN                 NaN   NaN
# 139               NaN           NaN                 NaN   NaN
# 140               NaN           NaN                 NaN   NaN
# 141               NaN           NaN                 NaN   NaN
#
# [142 rows x 82 columns]

# %%
df.to_csv("../data/kopi.csv", index=False)

# %%
# Initialize the Selenium WebDriver
driver = webdriver.Chrome()

# Navigate to the webpage
url = 'https://www.fairprice.com.sg/search?query=Tea'
driver.get(url)

# Wait for the page to load
time.sleep(10)

# Scroll to load more products
num_scrolls = 40
for _ in range(num_scrolls):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(10)

# Extract links to individual product pages
product_links = []
soup = BeautifulSoup(driver.page_source, 'html.parser')
product_cards = soup.find_all('div', class_='sc-2a85da88-0 fhLHEV product-container')

# Assuming product_cards contains the relevant div elements with class 'sc-2a85da88-0'
for card in product_cards:
    a_tag = card.find('a', class_='sc-2a85da88-3')
    if a_tag:
        product_link = a_tag['href']
        product_links.append(product_link)

# Extract nutritional data for each product
all_nutritional_data = []

for product_link in product_links:
    product_url = f'https://www.fairprice.com.sg{product_link}'
    driver.get(product_url)
    time.sleep(4)

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    nutritional_data = {}

    # Extracting the drink's volume
    volume = soup.find('span', class_='sc-aa673588-1 sc-d5ac8310-3 kZssPC jGBApJ')
    if volume:
        nutritional_data['Drink Volume'] = volume.text

    # Extracting the drink's name
    drink_name = soup.find('span', class_='sc-aa673588-1 drdope')
    if drink_name:
        nutritional_data['Drink Name'] = drink_name.text

    nutrient_list = soup.find('ul', class_='sc-ad6d339b-0 lhIfvG')
    if nutrient_list:
        nutrient_rows = nutrient_list.find_all('li', class_='sc-ad6d339b-1 iVtCiL')
        first_row = nutrient_rows[0]
        attributes_name = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU')
        attributes_value = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT')
        for attr_name, attr_value in zip(attributes_name, attributes_value):
            attribute_name = attr_name.text.strip()
            attribute_value = attr_value.text.strip()
            nutritional_data[attribute_name] = attribute_value
        for row in nutrient_rows[1:]:
            nutrient_name = row.find('span', class_='sc-ilhmMj').text.strip()
            nutrient_value = row.find('span', class_='sc-ilhmMj fQpIpK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT').text.strip()
            nutritional_data[nutrient_name] = nutrient_value

    all_nutritional_data.append(nutritional_data)

# Close the Selenium WebDriver
driver.quit()

# Create a DataFrame from the nutritional data
df = pd.DataFrame(all_nutritional_data)

# Remove the rows that have NaN in every column
# Drop rows where all columns except 'Drink Name' and 'Drink Volume' have NaN
df.dropna(subset=df.columns.difference(['Drink Name', 'Drink Volume']), how='all', inplace=True)

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# Print the DataFrame after removing rows with NaN
df
# Out:
#     Drink Volume                                         Drink Name  \
# 0   100 per pack  Lipton Yellow Label Tea Bags - International B...
# 1     12 x 300ml  Authentic Tea House Ayataka No Sugar Japanese ...
# 2       6 X 600G            Killiney Premium Milk Tea Family Bundle
# 3           1.5L                 Pokka Bottle Drink - Ice Lemon Tea
# 4      6 x 250ml                 Pokka Packet Drink - Ice Lemon Tea
# ..           ...                                                ...
# 87          400g  Cha Tra Mue Extra Gold Premium Tea Powder - Va...
# 88       1 X 30G  Nature's Superfoods Ceremonial Matcha Powder G...
# 89           1 L     Minor Figures Organic Barista Chai Concentrate
# 90         216 G                   Kim's Duet Instant Chrysanthemum
# 91    12 X 400ML          The GUTsy Captain Raspberry Kombucha ZERO
#
#              Attributes    Energy Protein Carbohydrate  Fat Cholesterol  \
# 0   Per Serving (100ml)        0g      0g           0g   0g         NaN
# 1   Per Serving (100ml)     0kcal      0g           0g  NaN          0g
# 2    Per Serving (null)       NaN    0.6g          NaN  NaN         NaN
# 3   Per Serving (250ml)   100kcal    0.0g        25.0g  NaN         NaN
# 4   Per Serving (250ml)   100kcal    0.0g        25.0g  NaN         NaN
# ..                  ...       ...     ...          ...  ...         ...
# 87      Per Serving (2)       NaN     NaN          NaN  NaN       300mg
# 88     Per Serving (1g)  0.01kcal      1g          NaN  NaN         0mg
# 89       Per Serving ()     105kj      0g           6g   0g         NaN
# 90   Per Serving (8.6g)       35g     NaN          NaN  NaN         NaN
# 91    Per Serving (100)       0kj      0g           0g   0g         NaN
#
#    Sugars Dietary Fibre  ... Calories From Fat   Salt Total Energy Total Fats  \
# 0     NaN           NaN  ...               NaN    NaN          NaN        NaN
# 1      0g            0g  ...               NaN    NaN          NaN        NaN
# 2   19.4g           NaN  ...               NaN    NaN          NaN        NaN
# 3     NaN           NaN  ...               NaN    NaN          NaN        NaN
# 4   25.0g           NaN  ...               NaN    NaN          NaN        NaN
# ..    ...           ...  ...               ...    ...          ...        ...
# 87    NaN           NaN  ...               NaN    NaN          NaN        NaN
# 88     0g            0g  ...               NaN    NaN          NaN        NaN
# 89     6g           NaN  ...               NaN     0g          NaN        NaN
# 90    NaN           NaN  ...               NaN    NaN          NaN        NaN
# 91    NaN           NaN  ...               NaN  0.01g          NaN        NaN
#
#    Saturated fat Amount per Saturated fats Total Carboyhdrate Dietary fiber  \
# 0            NaN        NaN            NaN                NaN           NaN
# 1            NaN        NaN            NaN                NaN           NaN
# 2            NaN        NaN            NaN                NaN           NaN
# 3            NaN        NaN            NaN                NaN           NaN
# 4            NaN        NaN            NaN                NaN           NaN
# ..           ...        ...            ...                ...           ...
# 87           20g        NaN            NaN                NaN           25g
# 88           NaN        NaN            NaN                NaN           NaN
# 89           NaN        NaN            NaN                NaN           NaN
# 90           NaN        NaN            NaN                NaN           NaN
# 91           NaN        NaN            NaN                NaN           NaN
#
#    Carbohyrate
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 87         NaN
# 88         NaN
# 89         NaN
# 90        8.7g
# 91         NaN
#
# [92 rows x 66 columns]

# %%
df.to_csv("../data/tea.csv", index=False)

# %%
# Initialize the Selenium WebDriver
driver = webdriver.Chrome()

# Navigate to the webpage
url = 'https://www.fairprice.com.sg/search?query=Juice'
driver.get(url)

# Wait for the page to load
time.sleep(10)

# Scroll to load more products
num_scrolls = 30
for _ in range(num_scrolls):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(10)

# Extract links to individual product pages
product_links = []
soup = BeautifulSoup(driver.page_source, 'html.parser')
product_cards = soup.find_all('div', class_='sc-2a85da88-0 fhLHEV product-container')

# Assuming product_cards contains the relevant div elements with class 'sc-2a85da88-0'
for card in product_cards:
    a_tag = card.find('a', class_='sc-2a85da88-3')
    if a_tag:
        product_link = a_tag['href']
        product_links.append(product_link)

# Extract nutritional data for each product
all_nutritional_data = []

for product_link in product_links:
    product_url = f'https://www.fairprice.com.sg{product_link}'
    driver.get(product_url)
    time.sleep(4)

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    nutritional_data = {}

    # Extracting the drink's volume
    volume = soup.find('span', class_='sc-aa673588-1 sc-d5ac8310-3 kZssPC jGBApJ')
    if volume:
        nutritional_data['Drink Volume'] = volume.text

    # Extracting the drink's name
    drink_name = soup.find('span', class_='sc-aa673588-1 drdope')
    if drink_name:
        nutritional_data['Drink Name'] = drink_name.text

    nutrient_list = soup.find('ul', class_='sc-ad6d339b-0 lhIfvG')
    if nutrient_list:
        nutrient_rows = nutrient_list.find_all('li', class_='sc-ad6d339b-1 iVtCiL')
        try:
            first_row = nutrient_rows[0]
            attributes_name = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU')
            attributes_value = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT')
            for attr_name, attr_value in zip(attributes_name, attributes_value):
                attribute_name = attr_name.text.strip()
                attribute_value = attr_value.text.strip()
                nutritional_data[attribute_name] = attribute_value
            for row in nutrient_rows[1:]:
                nutrient_name = row.find('span', class_='sc-ilhmMj').text.strip()
                nutrient_value = row.find('span', class_='sc-ilhmMj fQpIpK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT').text.strip()
                nutritional_data[nutrient_name] = nutrient_value
        except IndexError:
            continue

    all_nutritional_data.append(nutritional_data)

# Close the Selenium WebDriver
driver.quit()

# Create a DataFrame from the nutritional data
df = pd.DataFrame(all_nutritional_data)

# Remove the rows that have NaN in every column
# Drop rows where all columns except 'Drink Name' and 'Drink Volume' have NaN
df.dropna(subset=df.columns.difference(['Drink Name', 'Drink Volume']), how='all', inplace=True)

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# Print the DataFrame after removing rows with NaN
df
# Out:
#    Drink Volume                                         Drink Name  \
# 0         1.89L                 Sunkist Fruit Bottle Juice - Apple
# 1     6 x 250ml                  Pokka Packet Drink - Carrot Juice
# 2         1.89L                Sunkist Fruit Bottle Juice - Orange
# 3         946ml  F&N NutriWell Reduced Sugar Drink - Chrysanthe...
# 4            1L       Marigold 100% Packet Juice - Tropical Fruits
# ..          ...                                                ...
# 59    3 X 200ML        Marks & Spencer Percy Pig Fruit Juice Drink
# 60       330 ML          Wolf + Wald Organic Sparkling Apple Juice
# 61       250 ML              Muno Organic 100% Sea Buckthorn Juice
# 62    6 X 580ML                              BOMY BOMY Grape Juice
# 63           2L            Marigold Peel Fresh Bottle Juice - Lime
#
#              Attributes   Energy Protein Total Fat Saturated Fat Trans Fat  \
# 0   Per Serving (100ml)   42kcal    0.2g      0.0g          0.0g      0.0g
# 1    Per Serving (250g)  103kcal      0g        0g           NaN       NaN
# 2   Per Serving (250ml)  108kcal    0.5g      0.0g          0.0g      0.0g
# 3   Per Serving (250ml)   65kcal      0g        0g            0g       NaN
# 4   Per Serving (250ml)  118kcal    1.3g        0g            0g       NaN
# ..                  ...      ...     ...       ...           ...       ...
# 59       Per Serving ()   46kcal    0.4g       NaN          0.1g       NaN
# 60    Per Serving (330)      NaN    0.1g      0.1g           NaN       NaN
# 61    Per Serving (100)    236kj     NaN       NaN           NaN       NaN
# 62       Per Serving ()      NaN      0g       NaN           NaN       NaN
# 63  Per Serving (250ml)  110kcal      0g        0g            0g       NaN
#
#    Cholesterol Carbohydrate  ... sugars   Fats saturates Saturated Fats fats  \
# 0          0mg        10.4g  ...    NaN    NaN       NaN            NaN  NaN
# 1          NaN        25.8g  ...    NaN    NaN       NaN            NaN  NaN
# 2          0mg        26.3g  ...    NaN    NaN       NaN            NaN  NaN
# 3          0mg        15.5g  ...    NaN    NaN       NaN            NaN  NaN
# 4          0mg        28.3g  ...    NaN    NaN       NaN            NaN  NaN
# ..         ...          ...  ...    ...    ...       ...            ...  ...
# 59         NaN        10.3g  ...    NaN    NaN       NaN            NaN  NaN
# 60         NaN          NaN  ...    NaN    NaN       NaN            NaN  NaN
# 61         NaN          NaN  ...    NaN  0.65g       NaN            NaN  NaN
# 62         NaN          NaN  ...    NaN    NaN       NaN            NaN  NaN
# 63         0mg        27.3g  ...    NaN    NaN       NaN            NaN  NaN
#
#    Saturaed Fat Per Serving Total Calories Dietary Fiber Proteins
# 0           NaN         NaN            NaN           NaN      NaN
# 1           NaN         NaN            NaN           NaN      NaN
# 2           NaN         NaN            NaN           NaN      NaN
# 3           NaN         NaN            NaN           NaN      NaN
# 4           NaN         NaN            NaN           NaN      NaN
# ..          ...         ...            ...           ...      ...
# 59          NaN         NaN            NaN           NaN      NaN
# 60          NaN         NaN         24kcal            0g      NaN
# 61          NaN         NaN            NaN           NaN     1.1g
# 62          NaN         NaN            NaN           NaN      NaN
# 63          NaN         NaN            NaN           NaN      NaN
#
# [64 rows x 55 columns]

# %%
df.to_csv("../data/juice.csv", index=False)

# %%
# Initialize the Selenium WebDriver
driver = webdriver.Chrome()

# Navigate to the webpage
url = 'https://www.fairprice.com.sg/search?query=Drinks'
driver.get(url)

# Wait for the page to load
time.sleep(10)

# Scroll to load more products
num_scrolls = 80
for _ in range(num_scrolls):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(10)

# Extract links to individual product pages
product_links = []
soup = BeautifulSoup(driver.page_source, 'html.parser')
product_cards = soup.find_all('div', class_='sc-2a85da88-0 fhLHEV product-container')

# Assuming product_cards contains the relevant div elements with class 'sc-2a85da88-0'
for card in product_cards:
    a_tag = card.find('a', class_='sc-2a85da88-3')
    if a_tag:
        product_link = a_tag['href']
        product_links.append(product_link)

# Extract nutritional data for each product
all_nutritional_data = []

for product_link in product_links:
    product_url = f'https://www.fairprice.com.sg{product_link}'
    driver.get(product_url)
    time.sleep(4)

    soup = BeautifulSoup(driver.page_source, 'html.parser')

    nutritional_data = {}

    # Extracting the drink's volume
    volume = soup.find('span', class_='sc-aa673588-1 sc-d5ac8310-3 kZssPC jGBApJ')
    if volume:
        nutritional_data['Drink Volume'] = volume.text

    # Extracting the drink's name
    drink_name = soup.find('span', class_='sc-aa673588-1 drdope')
    if drink_name:
        nutritional_data['Drink Name'] = drink_name.text

    nutrient_list = soup.find('ul', class_='sc-ad6d339b-0 lhIfvG')
    if nutrient_list:
        nutrient_rows = nutrient_list.find_all('li', class_='sc-ad6d339b-1 iVtCiL')
        try:
            first_row = nutrient_rows[0]
            attributes_name = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU')
            attributes_value = first_row.find_all('span', class_='sc-kMjNwy dSxhfK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT')
            for attr_name, attr_value in zip(attributes_name, attributes_value):
                attribute_name = attr_name.text.strip()
                attribute_value = attr_value.text.strip()
                nutritional_data[attribute_name] = attribute_value
            for row in nutrient_rows[1:]:
                nutrient_name = row.find('span', class_='sc-ilhmMj').text.strip()
                nutrient_value = row.find('span', class_='sc-ilhmMj fQpIpK sc-khsqcC cWAEyU sc-ad6d339b-2 hKcaKT').text.strip()
                nutritional_data[nutrient_name] = nutrient_value
        except IndexError:
            continue

    all_nutritional_data.append(nutritional_data)

# Close the Selenium WebDriver
driver.quit()

# Create a DataFrame from the nutritional data
df = pd.DataFrame(all_nutritional_data)

# Remove the rows that have NaN in every column
# Drop rows where all columns except 'Drink Name' and 'Drink Volume' have NaN
df.dropna(subset=df.columns.difference(['Drink Name', 'Drink Volume']), how='all', inplace=True)

# Reset index after dropping rows
df.reset_index(drop=True, inplace=True)

# Print the DataFrame after removing rows with NaN
df
# Out:
#          Drink Volume                                         Drink Name  \
# 0    24 x 200ml (CTN)          Milo Chocolate Malt Milk UHT Packet Drink
# 1    12 x 320ml (CTN)                   Coca-Cola Can Drink - Zero Sugar
# 2           6 x 180ml              Coca-Cola Mini Can Drink - Zero Sugar
# 3    24 x 325ml (CTN)             100 Plus Isotonic Can Drink - Original
# 4    24 x 200ml (CTN)  Ribena Blackcurrant Fruit Packet Drink - Regular
# ..                ...                                                ...
# 184             500 G     Health Paradise Organic Black Soya Milk Powder
# 185            6 X 1L                     Minor Figures Barista Oat Milk
# 186            330 ML              Shozu Yuzu & Ume Sparkling Prebiotics
# 187             500 G     Health Paradise Instant Soya Milk Powder (NSA)
# 188            750 ML  Marks & Spencer Sparkling Sicilian Lemon & Bri...
#
#               Attributes  Energy Trans Fat Protein Total Fat Saturated Fat  \
# 0            Per Serving    1.7g       1mg    1.7g      0.9g            0g
# 1    Per Serving (100ml)   0kcal       NaN      0g        0g           NaN
# 2    Per Serving (180ml)   0kcal       NaN      0g        0g           NaN
# 3    Per Serving (100ml)  27kcal       NaN      0g        0g           NaN
# 4     Per Serving (100g)  43kcal        0g      0g        0g            0g
# ..                   ...     ...       ...     ...       ...           ...
# 184       Per Serving ()     NaN        0g      8g      4.5g         0.66g
# 185       Per Serving ()   410kJ       NaN    0.4g       NaN           NaN
# 186     Per Serving (0g)   146kj       NaN      0g       NaN           NaN
# 187       Per Serving ()     NaN        0g      6g      4.5g         0.66g
# 188       Per Serving ()  21kcal       NaN    0.1g       NaN          0.1g
#
#     Cholesterol Carbohydrate  ... Blueberry Extract Pomegranate Extract  \
# 0          9.5g           8g  ...               NaN                 NaN
# 1           NaN           0g  ...               NaN                 NaN
# 2           NaN           0g  ...               NaN                 NaN
# 3           NaN         6.8g  ...               NaN                 NaN
# 4           NaN        10.6g  ...               NaN                 NaN
# ..          ...          ...  ...               ...                 ...
# 184         0mg          NaN  ...               NaN                 NaN
# 185         NaN          19g  ...               NaN                 NaN
# 186         NaN           7g  ...               NaN                 NaN
# 187         0mg          NaN  ...               NaN                 NaN
# 188         NaN         5.1g  ...               NaN                 NaN
#
#     Sulfates pH Value Total Dissolved Solids  ats Serving Size: 4.5 tbsp  \
# 0        NaN      NaN                    NaN  NaN                    NaN
# 1        NaN      NaN                    NaN  NaN                    NaN
# 2        NaN      NaN                    NaN  NaN                    NaN
# 3        NaN      NaN                    NaN  NaN                    NaN
# 4        NaN      NaN                    NaN  NaN                    NaN
# ..       ...      ...                    ...  ...                    ...
# 184      NaN      NaN                    NaN  NaN                    30g
# 185      NaN      NaN                    NaN  NaN                    NaN
# 186      NaN      NaN                    NaN  NaN                    NaN
# 187      NaN      NaN                    NaN  NaN                    30g
# 188      NaN      NaN                    NaN  NaN                    NaN
#
#     Servings per container Saturated Fats Vit D
# 0                      NaN            NaN   NaN
# 1                      NaN            NaN   NaN
# 2                      NaN            NaN   NaN
# 3                      NaN            NaN   NaN
# 4                      NaN            NaN   NaN
# ..                     ...            ...   ...
# 184                  16pax            NaN   NaN
# 185                    NaN           0.4g   NaN
# 186                    NaN            NaN   NaN
# 187                  16pax            NaN  0mcg
# 188                    NaN            NaN   NaN
#
# [189 rows x 108 columns]

# %%
df.to_csv("../data/drinks.csv", index=False)
